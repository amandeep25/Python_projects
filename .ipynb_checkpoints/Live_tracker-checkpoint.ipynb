# 22     90737    1563         609         93071      90897       1565
# 23    186504     637       11469        200635     188528        638
# 24     34049     752         382         35274      34139        753
# 25   1259796    8904        8653       1279046    1261467       8926
# 26    162308    1958         900        165363     162504       1959
# 27    734768   17610        2933        756130     735574      17623
# 28   1238434    9469       17976       1268272    1240815       9481
# 29     38169     439         312         38977      38225        440
# 30   3364013   37932       31368       3439221    3369907      37946
# 31    770047    4107        8379        784631     772145       4107
# 32     99733     919         147        100813      99747        919
# 33    418531    7653        6553        434053     419840       7660
# 34   2022056   23399       12524       2060589    2024661      23404
# 35   1978555   21040       10630       2011569    1979878      21061
# 36  41760458  509488      370240      42723558   41843446     509872
#
#    death_reconsille total state_code
# 0                                 35
# 1                       4         28
# 2                                 12
# 3                       5         18
# 4                       1         10
# 5                       1         04
# 6                       1         22
# 7                                 26
# 8                       5         07
# 9                       3         30
# 10                     16         24
# 11                      7         06
# 12                      1         02
# 13                                01
# 14                                20
# 15                     26         29
# 16              130   304         32
# 17                                37
# 18                                31
# 19                      3         23
# 20                     35         27
# 21                      2         14
# 22                      2         17
# 23                      1         15
# 24                      1         13
# 25                     22         21
# 26                      1         34
# 27                     13         03
# 28                     12         08
# 29                      1         11
# 30                     14         33
# 31                                36
# 32                                16
# 33                      7         05
# 34                      5         09
# 35                     21         19
# 36              130   514

# %%
total_states = np.arange(len(df['state_name']))

# %% [markdown]
# EDA

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 9), dpi=80, facecolor='w', edgecolor='k')
plt.barh(total_states,df['positive'], align='center', alpha=0.5,  
                 color=(0.8,0,0),  
                 edgecolor=(0.5,0.2,0.8))
    
plt.yticks(total_states, df['state_name'])  
plt.xlim(1,max(df['positive'])+100) 
plt.xlabel('Positive Number of Cases')  
plt.title('Corona Virus Cases')  
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 9), dpi=80, facecolor='w', edgecolor='k')
plt.barh(total_states,df['active'], align='center', alpha=0.5,  
                 color=(0,0,0),  
                 edgecolor=(0.5,0.2,0.8))
    
plt.yticks(total_states, df['state_name'])  
plt.xlim(1,max(df['active'])+100) 
plt.xlabel('active Number of Cases')  
plt.title('Corona Virus Cases')  
plt.show()

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(10, 9), dpi=80, facecolor='w', edgecolor='k')
plt.barh(total_states,df['death'], align='center', alpha=0.5,  
                 color=(0.8,1,0.2),  
                 edgecolor=(0.5,0.2,0.8))
    
plt.yticks(total_states, df['state_name'])  
plt.xlim(1,max(df['death'])+100) 
plt.xlabel('death Number of Cases')  
plt.title('Corona Virus Cases')  
plt.show()

# %% [markdown]
# ### stack all columns in chart

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df = df.set_index('state_name',drop = True)

# %%
df.head()
# Out:
#                              sno  active  positive    cured  death  \
# state_name
# Andaman and Nicobar Islands    2     117      9981     9735    129
# Andhra Pradesh                 1   14726   2313212  2283788  14698
# Arunachal Pradesh              3     539     64066    63233    294
# Assam                          4    3639    723693   713444   6610
# Bihar                          5    1224    829050   815574  12252
#
#                              new_active  new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         103          9985       9753        129
# Andhra Pradesh                    12550       2313827    2286575      14702
# Arunachal Pradesh                   466         64110      63350        294
# Assam                              3247        723759     713897       6615
# Bihar                              1117        829209     815839      12253
#
#                             death_reconsille total state_code
# state_name
# Andaman and Nicobar Islands                                35
# Andhra Pradesh                                   4         28
# Arunachal Pradesh                                          12
# Assam                                            5         18
# Bihar                                            1         10

# %%
df.plot.barh(stacked = True,figsize = (10,10))
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df_1 = df.iloc[:,2:5]
df_1.plot.barh(color = {"cured":"red", "positive":"green", "death":"blue"},figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='state_name'>
